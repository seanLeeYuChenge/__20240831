# %%
import random
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)
# Out:
# 3
# 1
# 3
# 6
# 1
# 9
# 6
# 2
# 9
# 4
# 1
# 6
# 1
# 8
# 7
# 2
# 1
# 1
# 2
# 10
# 4
# 1
# 6
# 5
# 10
# 4
# 7
# 1
# 8
# 1
# 4
# 9
# 1
# 3
# 8
# 2
# 10
# 9
# 2
# 3
# 6
# 9
# 6
# 2
# 1
# 5
# 8
# 7
# 8
# 7
# 2
# 7
# 3
# 5
# 6
# 10
# 1
# 7
# 8
# 7
# 10
# 10
# 1
# 1
# 10
# 6
# 2
# 2
# 1
# 10
# 2
# 10
# 4
# 8
# 3
# 4
# 5
# 1
# 6
# 4
# 2
# 10
# 5
# 3
# 6
# 2
# 8
# 3
# 10
# 4
# 2
# 3
# 6
# 9
# 7
# 4
# 9
# 3
# 2
# 4

# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41926940436","type":"PushEvent","actor":{"id":74008303,"login":"apponboard2019","display_login":"apponboard2019","gravatar_id":"","url":"https://api.github.com/users/apponboard2019","avatar_url":"https://avatars.githubusercontent.com/u/74008303?"},"repo":{"id":561366239,"name":"apponboard2019/api","url":"https://api.github.com/repos/apponboard2019/api"},"payload":{"repository_id":561366239,"push_id":20235409912,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a7ee9fe4c950cc4168826a93caa1a96e03a10704","before":"0538d050e14c3d09993517c7830fd8b2e4ee55da","commits":[{"sha":"a7ee9fe4c950cc4168826a93caa1a96e03a10704","author":{"email":"74008303+apponboard2019@users.noreply.github.com","name":"apponboard2019"},"message":"Update file via API","distinct":true,"url":"https://api.github.com/repos/apponboard2019/api/commits/a7ee9fe4c950cc4168826a93caa1a96e03a10704"}]},"public":true,"created_at":"2024-09-14T08:04:02Z"},{"id":"41926940427","type":"CreateEvent","actor":{"id":95
# ...
